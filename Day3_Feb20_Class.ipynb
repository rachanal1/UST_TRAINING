# %%
#. 'r' open file for reading
#. 'w' open file for writing, creates new file if it doesnt exist or overwrite if exists
#. 'x'
#. 'a'
#. 'l'
#. 'b' 
#. '+' open for updating(read&write both)

# %%
lst=open('C:/Users/Administrator/Downloads/test.txt')
lst.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lst=open('C:/Users/Administrator/Downloads/test.txt')
#       2 lst.close()
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 44] No such file or directory: 'C:/Users/Administrator/Downloads/test.txt'

# %%
#writing

import os
os.getenv('C:/Users/python') #it gives home directory
lst=open('my.txt','w') #it creates file on home directory
lst.write('This is python training \n') #writing the text in file
lst.write('welcome to ust') #this writes 2nd line in file
lst.close() #closing file alwyas have to run this to make sure file get back and its safe

# %%
#Reading file

lst=open('my.txt','r')
lst.read()
# Out:
# 'This is python training \nwelcome to ust'

# %%
lst=open('my.txt','r')
lst.read(7) #it reads upto 7 only
# Out:
# 'This is'

# %%
 lst.tell() #it tells the pointer position
# Out:
# 0

# %%
lst.seek(5) #it sets pointer posituon to initial
# Out:
# 5

# %%
lst.tell()
# Out:
# 5

# %%
print(lst.read())
# Out:
# is python training
# welcome to ust

# %%
#we can read line by line using for loop

lst=open('my.txt','r')
for line in lst: #it reads line by line in file
    print(line)
# Out:
# This is python training
#
# welcome to ust

# %%
lst=open('my.txt','r')
for line in lst: #we can use this also to read line by line in file
    print(line.strip())
# Out:
# This is python training
# welcome to ust

# %%
#readline() function is alternative way to read line by line 
lst=open('my.txt','r')
lst.readline()
# Out:
# 'This is python training \n'

# %%
lst.readline()
# Out:
# 'welcome to ust'

# %%
#readlines() used to read entire content at a time
lst=open('my.txt','r')
lst.readlines()
# Out:
# ['This is python training \n', 'welcome to ust']

# %%
#Renaming and deleting
import os   #we need to import os module to perform this operation
os.rename('my.txt','test.txt')

# %%
lst=open('test.txt','r')
lst.readlines()
# Out:
# ['This is python training \n', 'welcome to ust']

# %%
os.remove('test.txt') #it will delete file

# %%
lst=open('test.txt','r') #no open is present as we deleted that it shows no file found
lst.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 lst=open('test.txt','r') #no open is present as we deleted that it shows no file found
#       2 lst.readlines()
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 44] No such file or directory: 'test.txt'

# %%
#python Directory & file management

import os
os.getcwd() #it gives current directory
#os.getenv
# Out:
# '/drive/notebooks/UST'

# %%
os.listdir(os.getcwdb())
# Out:
# [b'Day2.ipynb', b'Day3', b'Day3_Feb20_Class.ipynb', b'Untitled2.ipynb']

# %%
os.chdir('/drive/notebooks/UST') #it will take to this directory/Day3

# %%
os.getcwd()
# Out:
# '/drive/notebooks/UST'

# %%
#creating new directory

os.mkdir('rachana')

# %%
import os
os.listdir(os.getcwdb())

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime 
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 19, 9, 15, 692000)

# %%
#importinh all names

from math import *
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
print(sqrt(16))
# Out:
# 4.0
